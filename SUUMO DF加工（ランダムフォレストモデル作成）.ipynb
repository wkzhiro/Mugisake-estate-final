# %%
import pandas as pd
import numpy as np
import re
from matplotlib import pyplot as plt
# %matplotlib inline
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import optuna
import pickle
import json
import gspread
from google.oauth2.service_account import Credentials
from gspread_dataframe import get_as_dataframe
from gspread_dataframe import set_with_dataframe

# %%
## Googleスプレッドシートからデータ取得し格納
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from gspread_dataframe import get_as_dataframe
scope =['https://spreadsheets.google.com/feeds', 'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('grspread_key_mugisake.json', scope)
client = gspread.authorize(creds)
sheet = client.open("Mugisake_KA01").worksheet('sheet2')
df = get_as_dataframe(sheet)

# %%
#前処理
if_null_dell_column = ["name","price","address","layout","age","area","traffic_tx"]
df = df.dropna(subset=if_null_dell_column,axis = 0)

def get_station_info(item):
  dict = {}   
  if re.findall('バス',item) == ['バス']:
    dict["station"] = item.split('「')[1].split('」')[0]
    dict["time_walk"] = item.split('」')[1].split('歩')[1].split('分')[0]
    dict["time_bus"] = item.split('」')[1].split('バス')[1].split('分')[0]
  elif re.findall('km',item) == ['km']:
    dict["station"] = item.split('「')[1].split('」')[0]
    dict["time_walk"] = 0
    dict["time_bus"] = float(item.split('」')[1].split('車')[1].split('km')[0])/20*60
  else:
    dict["station"] = item.split('「')[1].split('」')[0]
    dict["time_walk"] = item.split('」')[1].split('歩')[1].split('分')[0]
    dict["time_bus"] = 0
  return dict

df["train_station"] = df["traffic_tx"].apply(lambda x :get_station_info(x)["station"])
df["time_walk"] = df["traffic_tx"].apply(lambda x :get_station_info(x)["time_walk"]).astype(float)
df["time_bus"] = df["traffic_tx"].apply(lambda x :get_station_info(x)["time_bus"]).astype(float)
df["age"] = df["age"].str[:4].replace("-","0").astype(float)
df["reform"] = df["reform"].str[:4].replace("-","0").astype(float)

def cal_room_num(text,s=0.5):
    if text.find("ワンルーム") >= 0:
        if text.find("S") >= 0:
            return 1+s
        else:
            return 1
    if text.find("1K") >= 0:
        if text.find("S") >= 0:
            return 1+s
        else:
            return 1
    if text.find("S") >=0:
        return int(re.sub(r'[^0-9]','',text))+1+s

    if text.find("2S") >=0:
        return int(re.sub(r'[^0-9]','',text))+2+s

    if text.find("3S") >=0:
        return int(re.sub(r'[^0-9]','',text))+3+s

    else:
        return int(re.sub(r'[^0-9]','',text))+1

df["room_num"] = df["layout"].apply(lambda x :cal_room_num(x))
def land_price(text):
    if text.find("秋葉原")>=0:
        return 742.9
    if text.find("新御徒町")>=0:
        return 441
    if text.find("浅草")>=0:
        return 390.3
    if text.find("本所吾妻橋")>=0:
        return 90
    if text.find("蔵前")>=0:
        return 103
    if text.find("南千住")>=0:
        return 218.6
    if text.find("北千住")>=0:
        return 238.7
    if text.find("青井")>=0:
        return 164.4
    if text.find("六町")>=0:
        return 127.8
    if text.find("八潮")>=0:
        return 77.8
    if text.find("三郷中央")>=0:
        return 50.9
    if text.find("南流山")>=0:
        return 62.9
    if text.find("流山セントラルパーク")>=0:
        return 60.1
    if text.find("流山おおたかの森")>=0:
        return 81
    if text.find("柏の葉キャンパス")>=0:
        return 60.1
    if text.find("柏たなか")>=0:
        return 56.5
    if text.find("守谷")>=0:
        return 41.2
df["train_station_price"] = df["train_station"].apply(lambda x: land_price(x)).astype(float)

def direction_price(text):
    if text.find("南")>=0:
        return 1
    if text.find("東")>=0:
        return 0.95
    if text.find("西")>=0:
        return 0.95
    if text.find("北")>=0:
        return 0.90
df["direction_price"] = df["direction"].apply(lambda x: direction_price(x)).astype(float)

#不要列の削除
drop_column = ['Unnamed: 19','Unnamed: 20','Unnamed: 21','Unnamed: 22','Unnamed: 23','Unnamed: 24','Unnamed: 25']
df = df.drop(drop_column,axis = 1)

# %%
#ランダムフォレストのモデル作成＆評価
x = df.loc[:,['price_kanri','price_tsumitate','age','floor','time_walk','time_bus','room_num','train_station_price','direction_price']]
y = df['price']
x_train, x_test, y_train, y_test = train_test_split(x,y)
model_random = RandomForestRegressor(n_estimators = 80, random_state = 0)
model_random.fit(x_train, y_train)
y_pred = model_random.predict(x_test)
print(model_random.score(x_train, y_train))
print(model_random.score(x_test, y_test))
mse = mean_squared_error(y_test, y_pred)
print(f'Test MSE: {mse}')
# Out:
# 0.963073570158355
# 0.8371898444224384
# Test MSE: 46550483629033.46

# %%
#optunaでランダムフォレストのハイパーパラメータ調整
def objective(trial):
    # ハイパーパラメータの設定
    n_estimators = trial.suggest_int('n_estimators', 50, 300)
    max_depth = trial.suggest_int('max_depth', 3, 10)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 10)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 5)

    #ランダムフォレストモデル
    model_random_optuna = RandomForestRegressor(n_estimators = 80, random_state = 0)

    # モデルの学習
    model_random_optuna.fit(x_train, y_train)

    # テストデータでの予測
    y_pred_optuna = model_random_optuna.predict(x_test)

    # 平均二乗誤差の計算
    mse = mean_squared_error(y_test, y_pred_optuna)
    return mse

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2023-03-04 11:05:46,659] A new study created in memory with name: no-name-3489c532-1f06-4d97-b512-f009d56a006a
# [I 2023-03-04 11:05:46,978] Trial 0 finished with value: 46550483629033.46 and parameters: {'n_estimators': 155, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:47,258] Trial 1 finished with value: 46550483629033.46 and parameters: {'n_estimators': 104, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:47,541] Trial 2 finished with value: 46550483629033.46 and parameters: {'n_estimators': 122, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:47,806] Trial 3 finished with value: 46550483629033.46 and parameters: {'n_estimators': 215, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:48,077] Trial 4 finished with value: 46550483629033.46 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:48,336] Trial 5 finished with value: 46550483629033.46 and parameters: {'n_estimators': 117, 'max_depth': 3, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:48,600] Trial 6 finished with value: 46550483629033.46 and parameters: {'n_estimators': 126, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:48,865] Trial 7 finished with value: 46550483629033.46 and parameters: {'n_estimators': 83, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:49,139] Trial 8 finished with value: 46550483629033.46 and parameters: {'n_estimators': 139, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:49,437] Trial 9 finished with value: 46550483629033.46 and parameters: {'n_estimators': 69, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:49,702] Trial 10 finished with value: 46550483629033.46 and parameters: {'n_estimators': 296, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:49,971] Trial 11 finished with value: 46550483629033.46 and parameters: {'n_estimators': 180, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:50,241] Trial 12 finished with value: 46550483629033.46 and parameters: {'n_estimators': 186, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:50,508] Trial 13 finished with value: 46550483629033.46 and parameters: {'n_estimators': 90, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:50,787] Trial 14 finished with value: 46550483629033.46 and parameters: {'n_estimators': 50, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:51,128] Trial 15 finished with value: 46550483629033.46 and parameters: {'n_estimators': 155, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:51,402] Trial 16 finished with value: 46550483629033.46 and parameters: {'n_estimators': 251, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:51,690] Trial 17 finished with value: 46550483629033.46 and parameters: {'n_estimators': 101, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:52,003] Trial 18 finished with value: 46550483629033.46 and parameters: {'n_estimators': 164, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:52,272] Trial 19 finished with value: 46550483629033.46 and parameters: {'n_estimators': 200, 'max_depth': 8, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:52,544] Trial 20 finished with value: 46550483629033.46 and parameters: {'n_estimators': 145, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:52,815] Trial 21 finished with value: 46550483629033.46 and parameters: {'n_estimators': 106, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:53,090] Trial 22 finished with value: 46550483629033.46 and parameters: {'n_estimators': 130, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:53,360] Trial 23 finished with value: 46550483629033.46 and parameters: {'n_estimators': 68, 'max_depth': 6, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:53,630] Trial 24 finished with value: 46550483629033.46 and parameters: {'n_estimators': 159, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:53,899] Trial 25 finished with value: 46550483629033.46 and parameters: {'n_estimators': 121, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:54,176] Trial 26 finished with value: 46550483629033.46 and parameters: {'n_estimators': 106, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:54,449] Trial 27 finished with value: 46550483629033.46 and parameters: {'n_estimators': 84, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:54,720] Trial 28 finished with value: 46550483629033.46 and parameters: {'n_estimators': 178, 'max_depth': 5, 'min_samples_split': 8, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:54,993] Trial 29 finished with value: 46550483629033.46 and parameters: {'n_estimators': 205, 'max_depth': 10, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:55,265] Trial 30 finished with value: 46550483629033.46 and parameters: {'n_estimators': 229, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:55,536] Trial 31 finished with value: 46550483629033.46 and parameters: {'n_estimators': 241, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:55,809] Trial 32 finished with value: 46550483629033.46 and parameters: {'n_estimators': 208, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:56,094] Trial 33 finished with value: 46550483629033.46 and parameters: {'n_estimators': 267, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:56,366] Trial 34 finished with value: 46550483629033.46 and parameters: {'n_estimators': 139, 'max_depth': 9, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:56,716] Trial 35 finished with value: 46550483629033.46 and parameters: {'n_estimators': 119, 'max_depth': 3, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:56,997] Trial 36 finished with value: 46550483629033.46 and parameters: {'n_estimators': 147, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:57,343] Trial 37 finished with value: 46550483629033.46 and parameters: {'n_estimators': 189, 'max_depth': 8, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:57,617] Trial 38 finished with value: 46550483629033.46 and parameters: {'n_estimators': 217, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:57,905] Trial 39 finished with value: 46550483629033.46 and parameters: {'n_estimators': 167, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:58,192] Trial 40 finished with value: 46550483629033.46 and parameters: {'n_estimators': 134, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:58,465] Trial 41 finished with value: 46550483629033.46 and parameters: {'n_estimators': 269, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:58,736] Trial 42 finished with value: 46550483629033.46 and parameters: {'n_estimators': 225, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:59,009] Trial 43 finished with value: 46550483629033.46 and parameters: {'n_estimators': 194, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:59,282] Trial 44 finished with value: 46550483629033.46 and parameters: {'n_estimators': 94, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:59,556] Trial 45 finished with value: 46550483629033.46 and parameters: {'n_estimators': 76, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:05:59,828] Trial 46 finished with value: 46550483629033.46 and parameters: {'n_estimators': 241, 'max_depth': 10, 'min_samples_split': 8, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:00,101] Trial 47 finished with value: 46550483629033.46 and parameters: {'n_estimators': 54, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:00,372] Trial 48 finished with value: 46550483629033.46 and parameters: {'n_estimators': 296, 'max_depth': 6, 'min_samples_split': 5, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:00,644] Trial 49 finished with value: 46550483629033.46 and parameters: {'n_estimators': 113, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:00,917] Trial 50 finished with value: 46550483629033.46 and parameters: {'n_estimators': 148, 'max_depth': 7, 'min_samples_split': 2, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:01,197] Trial 51 finished with value: 46550483629033.46 and parameters: {'n_estimators': 128, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:01,477] Trial 52 finished with value: 46550483629033.46 and parameters: {'n_estimators': 173, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:01,745] Trial 53 finished with value: 46550483629033.46 and parameters: {'n_estimators': 114, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:02,017] Trial 54 finished with value: 46550483629033.46 and parameters: {'n_estimators': 97, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:02,285] Trial 55 finished with value: 46550483629033.46 and parameters: {'n_estimators': 155, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:02,566] Trial 56 finished with value: 46550483629033.46 and parameters: {'n_estimators': 126, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:02,835] Trial 57 finished with value: 46550483629033.46 and parameters: {'n_estimators': 86, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:03,103] Trial 58 finished with value: 46550483629033.46 and parameters: {'n_estimators': 108, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:03,369] Trial 59 finished with value: 46550483629033.46 and parameters: {'n_estimators': 213, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:03,661] Trial 60 finished with value: 46550483629033.46 and parameters: {'n_estimators': 181, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:03,962] Trial 61 finished with value: 46550483629033.46 and parameters: {'n_estimators': 139, 'max_depth': 8, 'min_samples_split': 6, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:04,275] Trial 62 finished with value: 46550483629033.46 and parameters: {'n_estimators': 101, 'max_depth': 9, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:04,592] Trial 63 finished with value: 46550483629033.46 and parameters: {'n_estimators': 120, 'max_depth': 7, 'min_samples_split': 6, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:04,921] Trial 64 finished with value: 46550483629033.46 and parameters: {'n_estimators': 161, 'max_depth': 6, 'min_samples_split': 7, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:05,230] Trial 65 finished with value: 46550483629033.46 and parameters: {'n_estimators': 137, 'max_depth': 8, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:05,542] Trial 66 finished with value: 46550483629033.46 and parameters: {'n_estimators': 76, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:05,852] Trial 67 finished with value: 46550483629033.46 and parameters: {'n_estimators': 152, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:06,122] Trial 68 finished with value: 46550483629033.46 and parameters: {'n_estimators': 236, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:06,389] Trial 69 finished with value: 46550483629033.46 and parameters: {'n_estimators': 251, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:06,656] Trial 70 finished with value: 46550483629033.46 and parameters: {'n_estimators': 274, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:06,925] Trial 71 finished with value: 46550483629033.46 and parameters: {'n_estimators': 65, 'max_depth': 3, 'min_samples_split': 8, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:07,196] Trial 72 finished with value: 46550483629033.46 and parameters: {'n_estimators': 91, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:07,465] Trial 73 finished with value: 46550483629033.46 and parameters: {'n_estimators': 80, 'max_depth': 3, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:07,735] Trial 74 finished with value: 46550483629033.46 and parameters: {'n_estimators': 111, 'max_depth': 9, 'min_samples_split': 10, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:08,002] Trial 75 finished with value: 46550483629033.46 and parameters: {'n_estimators': 101, 'max_depth': 4, 'min_samples_split': 7, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:08,272] Trial 76 finished with value: 46550483629033.46 and parameters: {'n_estimators': 200, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:08,539] Trial 77 finished with value: 46550483629033.46 and parameters: {'n_estimators': 126, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:08,808] Trial 78 finished with value: 46550483629033.46 and parameters: {'n_estimators': 62, 'max_depth': 6, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:09,086] Trial 79 finished with value: 46550483629033.46 and parameters: {'n_estimators': 133, 'max_depth': 7, 'min_samples_split': 10, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:09,355] Trial 80 finished with value: 46550483629033.46 and parameters: {'n_estimators': 144, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:09,625] Trial 81 finished with value: 46550483629033.46 and parameters: {'n_estimators': 120, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:09,895] Trial 82 finished with value: 46550483629033.46 and parameters: {'n_estimators': 168, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:10,166] Trial 83 finished with value: 46550483629033.46 and parameters: {'n_estimators': 221, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:10,434] Trial 84 finished with value: 46550483629033.46 and parameters: {'n_estimators': 144, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:10,705] Trial 85 finished with value: 46550483629033.46 and parameters: {'n_estimators': 126, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:10,977] Trial 86 finished with value: 46550483629033.46 and parameters: {'n_estimators': 101, 'max_depth': 6, 'min_samples_split': 4, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:11,252] Trial 87 finished with value: 46550483629033.46 and parameters: {'n_estimators': 107, 'max_depth': 3, 'min_samples_split': 5, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:11,529] Trial 88 finished with value: 46550483629033.46 and parameters: {'n_estimators': 86, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:11,801] Trial 89 finished with value: 46550483629033.46 and parameters: {'n_estimators': 115, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:12,076] Trial 90 finished with value: 46550483629033.46 and parameters: {'n_estimators': 140, 'max_depth': 5, 'min_samples_split': 7, 'min_samples_leaf': 4}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:12,345] Trial 91 finished with value: 46550483629033.46 and parameters: {'n_estimators': 94, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:12,619] Trial 92 finished with value: 46550483629033.46 and parameters: {'n_estimators': 55, 'max_depth': 6, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:12,888] Trial 93 finished with value: 46550483629033.46 and parameters: {'n_estimators': 70, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:13,159] Trial 94 finished with value: 46550483629033.46 and parameters: {'n_estimators': 152, 'max_depth': 8, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:13,427] Trial 95 finished with value: 46550483629033.46 and parameters: {'n_estimators': 130, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 1}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:13,699] Trial 96 finished with value: 46550483629033.46 and parameters: {'n_estimators': 254, 'max_depth': 6, 'min_samples_split': 9, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:14,051] Trial 97 finished with value: 46550483629033.46 and parameters: {'n_estimators': 233, 'max_depth': 10, 'min_samples_split': 4, 'min_samples_leaf': 2}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:14,357] Trial 98 finished with value: 46550483629033.46 and parameters: {'n_estimators': 189, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 5}. Best is trial 0 with value: 46550483629033.46.
# [I 2023-03-04 11:06:14,629] Trial 99 finished with value: 46550483629033.46 and parameters: {'n_estimators': 76, 'max_depth': 7, 'min_samples_split': 8, 'min_samples_leaf': 3}. Best is trial 0 with value: 46550483629033.46.

# %%
best_params = study.best_params
print(f'Best parameters: {best_params}')
# Out:
# Best parameters: {'n_estimators': 155, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 4}

# %%
#optunaによるベストパラメータでのモデル作成＆評価
model_random_optuna = RandomForestRegressor(n_estimators=best_params['n_estimators'],
                            max_depth=best_params['max_depth'],
                            min_samples_split=best_params['min_samples_split'],
                            min_samples_leaf=best_params['min_samples_leaf'],
                            random_state=42)
model_random_optuna.fit(x_train, y_train)
y_pred_optuna = rf.predict(x_test)
mse = mean_squared_error(y_test, y_pred_optuna)
print(model_random_optuna.score(x_train, y_train))
print(model_random_optuna.score(x_test, y_test))
print(f'Test MSE: {mse}')
# Out:
# 0.7675662197491881
# 0.7523502665440851
# Test MSE: 22531300787875.215

# %%
pickle.dump(model_random_optuna,open('SUUMO_random_forest_regressor_byoptuna_model.pkl','wb'))
